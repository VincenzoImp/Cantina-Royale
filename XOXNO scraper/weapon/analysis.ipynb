# %%
import matplotlib.pyplot as plt
import json
import pandas as pd

# %%
with open('data.json') as f:
    data = json.load(f)

# %%
l = []
for k, v in data.items():
    try:
        price = v['price']
        level = v['dynamic_dict']['starLevel']
        weapon = v['metadata_dict']['name']
        code = k
        l.append((price, level, weapon, code))
    except:
        print(k)
# Out:
# CRWEAPONS-e5ab49-033a
# CRWEAPONS-e5ab49-05e4

# %%
df = pd.DataFrame(l, columns=['price', 'level', 'weapon', 'code'])

# %%
df1 = df[df['level'] == 1]
df1 = df1.sort_values(by='price')
df1
# Out:
#      price  level        weapon                   code
# 0    0.099      1     Railgun-X  CRWEAPONS-e5ab49-0ec7
# 1    0.100      1   Tesla Gun X  CRWEAPONS-e5ab49-074d
# 2    0.100      1   Tesla Gun X  CRWEAPONS-e5ab49-04f0
# 3    0.102      1   Tesla Gun X  CRWEAPONS-e5ab49-0e93
# 4    0.106      1     Railgun-X  CRWEAPONS-e5ab49-0fe1
# 5    0.106      1  Mortar Gun X  CRWEAPONS-e5ab49-0fd1
# 6    0.106      1  Mortar Gun X  CRWEAPONS-e5ab49-0f7b
# 7    0.106      1   Tesla Gun X  CRWEAPONS-e5ab49-0efc
# 8    0.108      1  Mortar Gun X  CRWEAPONS-e5ab49-0fec
# 9    0.108      1  Mortar Gun X  CRWEAPONS-e5ab49-0fc1
# 13   0.110      1   Tesla Gun X  CRWEAPONS-e5ab49-1012
# 11   0.110      1   Tesla Gun X  CRWEAPONS-e5ab49-1017
# 12   0.110      1  Mortar Gun X  CRWEAPONS-e5ab49-013e
# 17   0.139      1  Mortar Gun X  CRWEAPONS-e5ab49-0f05
# 24   0.149      1     Blaster-X  CRWEAPONS-e5ab49-03a5
# 25   0.149      1     Blaster-X  CRWEAPONS-e5ab49-0302
# 26   0.150      1     Blaster-X  CRWEAPONS-e5ab49-1005
# 34   0.194      1  Mortar Gun X  CRWEAPONS-e5ab49-027c
# 35   0.194      1  Mortar Gun X  CRWEAPONS-e5ab49-0348
# 36   0.196      1     Blaster-X  CRWEAPONS-e5ab49-075c
# 37   0.200      1   Tesla Gun X    CRWEAPONS-e5ab49-52
# 42   0.210      1     Blaster-X  CRWEAPONS-e5ab49-0667
# 45   0.220      1   Boomstick-X  CRWEAPONS-e5ab49-04a8
# 44   0.220      1   Boomstick-X  CRWEAPONS-e5ab49-06f2
# 55   0.295      1     Railgun-X  CRWEAPONS-e5ab49-0472
# 56   0.299      1   Tesla Gun X  CRWEAPONS-e5ab49-071e
# 68   0.390      1     Blaster-X  CRWEAPONS-e5ab49-06c4
# 78   0.440      1     Railgun-X    CRWEAPONS-e5ab49-fc
# 84   0.500      1  Mortar Gun X  CRWEAPONS-e5ab49-0220
# 86   0.500      1   Boomstick-X  CRWEAPONS-e5ab49-0320
# 87   0.500      1     Railgun-X  CRWEAPONS-e5ab49-022a
# 93   0.590      1  Mortar Gun X  CRWEAPONS-e5ab49-0544
# 101  0.670      1   Tesla Gun X  CRWEAPONS-e5ab49-0232
# 106  1.000      1   Tesla Gun X    CRWEAPONS-e5ab49-bb
# 113  1.000      1     Railgun-X  CRWEAPONS-e5ab49-0112
# 112  1.000      1     Railgun-X    CRWEAPONS-e5ab49-8d
# 111  1.000      1     Railgun-X    CRWEAPONS-e5ab49-7a
# 104  1.000      1     Railgun-X  CRWEAPONS-e5ab49-0108
# 105  1.000      1     Railgun-X  CRWEAPONS-e5ab49-0149
# 107  1.000      1     Railgun-X    CRWEAPONS-e5ab49-b8
# 119  1.110      1  Mortar Gun X  CRWEAPONS-e5ab49-0408
# 121  1.890      1  Mortar Gun X  CRWEAPONS-e5ab49-02c7
# 127  2.000      1   Boomstick-X  CRWEAPONS-e5ab49-0229
# 132  2.100      1     Railgun-X    CRWEAPONS-e5ab49-fb
# 133  2.100      1     Railgun-X  CRWEAPONS-e5ab49-0107
# 130  2.100      1     Railgun-X    CRWEAPONS-e5ab49-29
# 131  2.100      1     Railgun-X    CRWEAPONS-e5ab49-e1
# 135  2.100      1   Tesla Gun X    CRWEAPONS-e5ab49-a5

# %%
df2 = df[df['level'] == 2]
df2 = df2.sort_values(by='price')
df2
# Out:
#      price  level        weapon                   code
# 10   0.108      2   Boomstick-X  CRWEAPONS-e5ab49-0e9c
# 14   0.130      2   Boomstick-X  CRWEAPONS-e5ab49-0ed3
# 15   0.130      2     Railgun-X  CRWEAPONS-e5ab49-0fee
# 16   0.138      2  Mortar Gun X  CRWEAPONS-e5ab49-0f6b
# 18   0.140      2   Tesla Gun X  CRWEAPONS-e5ab49-0c61
# 19   0.145      2   Tesla Gun X  CRWEAPONS-e5ab49-0fb1
# 20   0.148      2     Blaster-X  CRWEAPONS-e5ab49-0f90
# 21   0.149      2  Mortar Gun X  CRWEAPONS-e5ab49-0ee1
# 23   0.149      2     Railgun-X  CRWEAPONS-e5ab49-0729
# 29   0.150      2  Mortar Gun X  CRWEAPONS-e5ab49-0d84
# 30   0.150      2  Mortar Gun X  CRWEAPONS-e5ab49-0b42
# 33   0.190      2     Railgun-X  CRWEAPONS-e5ab49-0999
# 31   0.190      2     Blaster-X  CRWEAPONS-e5ab49-0db8
# 32   0.190      2     Railgun-X  CRWEAPONS-e5ab49-0387
# 38   0.200      2     Blaster-X  CRWEAPONS-e5ab49-09e6
# 39   0.200      2   Boomstick-X  CRWEAPONS-e5ab49-01fb
# 41   0.200      2     Blaster-X  CRWEAPONS-e5ab49-0a39
# 43   0.214      2     Blaster-X  CRWEAPONS-e5ab49-0a22
# 46   0.220      2     Blaster-X  CRWEAPONS-e5ab49-0ff8
# 48   0.260      2     Blaster-X  CRWEAPONS-e5ab49-0c10
# 50   0.270      2   Boomstick-X  CRWEAPONS-e5ab49-0fcd
# 49   0.270      2   Tesla Gun X  CRWEAPONS-e5ab49-0fcc
# 51   0.270      2  Mortar Gun X  CRWEAPONS-e5ab49-09ed
# 60   0.300      2   Boomstick-X  CRWEAPONS-e5ab49-0be9
# 59   0.300      2   Tesla Gun X  CRWEAPONS-e5ab49-09d8
# 67   0.390      2  Mortar Gun X  CRWEAPONS-e5ab49-072a
# 72   0.400      2     Railgun-X  CRWEAPONS-e5ab49-0bd7
# 73   0.400      2  Mortar Gun X  CRWEAPONS-e5ab49-0654
# 74   0.400      2   Boomstick-X    CRWEAPONS-e5ab49-a1
# 79   0.450      2   Tesla Gun X  CRWEAPONS-e5ab49-0d01
# 82   0.450      2   Tesla Gun X  CRWEAPONS-e5ab49-048a
# 85   0.500      2  Mortar Gun X  CRWEAPONS-e5ab49-08ce
# 90   0.540      2   Boomstick-X  CRWEAPONS-e5ab49-06b6
# 92   0.580      2   Tesla Gun X    CRWEAPONS-e5ab49-46
# 97   0.600      2     Blaster-X  CRWEAPONS-e5ab49-0553
# 94   0.600      2   Boomstick-X  CRWEAPONS-e5ab49-06e6
# 110  1.000      2     Blaster-X  CRWEAPONS-e5ab49-0313
# 109  1.000      2     Blaster-X  CRWEAPONS-e5ab49-028a
# 102  1.000      2   Boomstick-X  CRWEAPONS-e5ab49-09fb
# 103  1.000      2     Blaster-X  CRWEAPONS-e5ab49-09ff
# 115  1.070      2     Railgun-X  CRWEAPONS-e5ab49-07d0
# 116  1.100      2     Railgun-X  CRWEAPONS-e5ab49-0668
# 118  1.100      2   Boomstick-X  CRWEAPONS-e5ab49-0123
# 120  1.600      2     Blaster-X  CRWEAPONS-e5ab49-02f5
# 125  2.000      2   Tesla Gun X  CRWEAPONS-e5ab49-03fb
# 128  2.000      2   Tesla Gun X  CRWEAPONS-e5ab49-0341
# 129  2.100      2   Boomstick-X  CRWEAPONS-e5ab49-0279
# 134  2.100      2   Tesla Gun X    CRWEAPONS-e5ab49-9d
# 136  2.450      2  Mortar Gun X  CRWEAPONS-e5ab49-0b7a
# 137  2.500      2  Mortar Gun X  CRWEAPONS-e5ab49-08e6

# %%
df3 = df[df['level'] == 3]
df3 = df3.sort_values(by='price')
df3
# Out:
#         price  level        weapon                   code
# 28      0.150      3   Tesla Gun X  CRWEAPONS-e5ab49-0931
# 47      0.220      3     Railgun-X  CRWEAPONS-e5ab49-081d
# 52      0.280      3  Mortar Gun X  CRWEAPONS-e5ab49-0fef
# 53      0.280      3  Mortar Gun X  CRWEAPONS-e5ab49-0ffb
# 54      0.290      3   Boomstick-X  CRWEAPONS-e5ab49-0f45
# 57      0.300      3   Boomstick-X  CRWEAPONS-e5ab49-0ffe
# 58      0.300      3     Railgun-X  CRWEAPONS-e5ab49-0f68
# 61      0.300      3   Tesla Gun X  CRWEAPONS-e5ab49-0fe8
# 62      0.300      3   Tesla Gun X  CRWEAPONS-e5ab49-0fe7
# 63      0.303      3   Tesla Gun X  CRWEAPONS-e5ab49-0eb0
# 64      0.319      3  Mortar Gun X  CRWEAPONS-e5ab49-0fc6
# 65      0.320      3     Railgun-X  CRWEAPONS-e5ab49-0f35
# 66      0.380      3     Blaster-X  CRWEAPONS-e5ab49-0fc0
# 75      0.400      3   Tesla Gun X  CRWEAPONS-e5ab49-0a25
# 71      0.400      3     Blaster-X  CRWEAPONS-e5ab49-0f41
# 69      0.400      3     Railgun-X  CRWEAPONS-e5ab49-0eae
# 70      0.400      3     Railgun-X  CRWEAPONS-e5ab49-06e4
# 77      0.430      3     Blaster-X  CRWEAPONS-e5ab49-0f3f
# 80      0.450      3     Railgun-X  CRWEAPONS-e5ab49-0a73
# 81      0.450      3   Tesla Gun X  CRWEAPONS-e5ab49-0f46
# 83      0.450      3     Railgun-X  CRWEAPONS-e5ab49-09ba
# 89      0.500      3   Tesla Gun X  CRWEAPONS-e5ab49-09ea
# 91      0.540      3     Blaster-X  CRWEAPONS-e5ab49-0fa5
# 95      0.600      3   Boomstick-X  CRWEAPONS-e5ab49-0cd5
# 96      0.600      3     Railgun-X  CRWEAPONS-e5ab49-0bcb
# 98      0.650      3     Blaster-X  CRWEAPONS-e5ab49-0bd6
# 99      0.650      3     Railgun-X    CRWEAPONS-e5ab49-f3
# 100     0.650      3     Railgun-X  CRWEAPONS-e5ab49-0bd3
# 117     1.100      3   Boomstick-X  CRWEAPONS-e5ab49-076e
# 139  1500.000      3   Boomstick-X  CRWEAPONS-e5ab49-0a6d
# 140  1500.000      3   Tesla Gun X  CRWEAPONS-e5ab49-0628

# %%
df4 = df[df['level'] == 4]
df4 = df4.sort_values(by='price')
df4
# Out:
#        price  level        weapon                   code
# 27      0.15      4   Tesla Gun X  CRWEAPONS-e5ab49-0810
# 40      0.20      4   Tesla Gun X  CRWEAPONS-e5ab49-0cdc
# 88      0.50      4     Blaster-X  CRWEAPONS-e5ab49-09f9
# 108     1.00      4   Boomstick-X  CRWEAPONS-e5ab49-0f84
# 114     1.07      4     Blaster-X  CRWEAPONS-e5ab49-0670
# 122     1.95      4     Blaster-X  CRWEAPONS-e5ab49-0a34
# 123     1.98      4     Blaster-X  CRWEAPONS-e5ab49-0a2f
# 124     1.99      4     Blaster-X  CRWEAPONS-e5ab49-0fbf
# 126     2.00      4  Mortar Gun X  CRWEAPONS-e5ab49-0f0e
# 138     9.00      4  Mortar Gun X  CRWEAPONS-e5ab49-0c43
# 141  3000.00      4   Boomstick-X  CRWEAPONS-e5ab49-0a6f

# %%
df5 = df[df['level'] == 5]
df5 = df5.sort_values(by='price')
df5
# Out:
#     price  level     weapon                   code
# 22  0.149      5  Blaster-X  CRWEAPONS-e5ab49-0300
# 76  0.420      5  Railgun-X  CRWEAPONS-e5ab49-0b0c

# %%
df6 = df[df['level'] == 6]
df6 = df6.sort_values(by='price')
df6
# Out:
# Empty DataFrame
# Columns: [price, level, weapon, code]
# Index: []

# %%
l = [i for i in l if i[0] < 1.5]

# %%
[x for x in l if x[1] > 1]
# Out:
# [(0.108, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0e9c'),
#  (0.13, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0ed3'),
#  (0.13, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0fee'),
#  (0.138, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0f6b'),
#  (0.14, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0c61'),
#  (0.145, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fb1'),
#  (0.148, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0f90'),
#  (0.149, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0ee1'),
#  (0.149, 5, 'Blaster-X', 'CRWEAPONS-e5ab49-0300'),
#  (0.149, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0729'),
#  (0.15, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0810'),
#  (0.15, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0931'),
#  (0.15, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0d84'),
#  (0.15, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0b42'),
#  (0.19, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0db8'),
#  (0.19, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0387'),
#  (0.19, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0999'),
#  (0.2, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-09e6'),
#  (0.2, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-01fb'),
#  (0.2, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0cdc'),
#  (0.2, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0a39'),
#  (0.214, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0a22'),
#  (0.22, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0ff8'),
#  (0.22, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-081d'),
#  (0.26, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0c10'),
#  (0.27, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fcc'),
#  (0.27, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0fcd'),
#  (0.27, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-09ed'),
#  (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fef'),
#  (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0ffb'),
#  (0.29, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0f45'),
#  (0.3, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0ffe'),
#  (0.3, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f68'),
#  (0.3, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-09d8'),
#  (0.3, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0be9'),
#  (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe8'),
#  (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe7'),
#  (0.303, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0eb0'),
#  (0.319, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fc6'),
#  (0.32, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f35'),
#  (0.38, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0fc0'),
#  (0.39, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-072a'),
#  (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0eae'),
#  (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-06e4'),
#  (0.4, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f41'),
#  (0.4, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0bd7'),
#  (0.4, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0654'),
#  (0.4, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-a1'),
#  (0.4, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0a25'),
#  (0.42, 5, 'Railgun-X', 'CRWEAPONS-e5ab49-0b0c'),
#  (0.43, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f3f'),
#  (0.45, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0d01'),
#  (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0a73'),
#  (0.45, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0f46'),
#  (0.45, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-048a'),
#  (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-09ba'),
#  (0.5, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-08ce'),
#  (0.5, 4, 'Blaster-X', 'CRWEAPONS-e5ab49-09f9'),
#  (0.5, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-09ea'),
#  (0.54, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-06b6'),
#  (0.54, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0fa5'),
#  (0.58, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-46'),
#  (0.6, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-06e6'),
#  (0.6, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0cd5'),
#  (0.6, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0bcb'),
#  (0.6, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0553'),
#  (0.65, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0bd6'),
#  (0.65, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-f3'),
#  (0.65, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0bd3'),
#  (1.0, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-09fb'),
#  (1.0, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-09ff'),
#  (1.0, 4, 'Boomstick-X', 'CRWEAPONS-e5ab49-0f84'),
#  (1.0, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-028a'),
#  (1.0, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0313'),
#  (1.07, 4, 'Blaster-X', 'CRWEAPONS-e5ab49-0670'),
#  (1.07, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-07d0'),
#  (1.1, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0668'),
#  (1.1, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-076e'),
#  (1.1, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0123')]

# %%
plt.scatter([x[0] for x in l], [x[1] for x in l])
plt.xlabel('Price')
plt.ylabel('Level')
# label dot with code with angolo 45 degree
for i in l:
    plt.annotate(i[3][-4:], (i[0], i[1]), rotation=45)
plt.show()

# %%
for x in l:
    if x[1] > 2:
        print(x)
# Out:
# (0.149, 5, 'Blaster-X', 'CRWEAPONS-e5ab49-0300')
# (0.15, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0810')
# (0.15, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0931')
# (0.2, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0cdc')
# (0.22, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-081d')
# (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fef')
# (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0ffb')
# (0.29, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0f45')
# (0.3, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0ffe')
# (0.3, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f68')
# (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe8')
# (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe7')
# (0.303, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0eb0')
# (0.319, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fc6')
# (0.32, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f35')
# (0.38, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0fc0')
# (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0eae')
# (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-06e4')
# (0.4, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f41')
# (0.4, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0a25')
# (0.42, 5, 'Railgun-X', 'CRWEAPONS-e5ab49-0b0c')
# (0.43, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f3f')
# (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0a73')
# (0.45, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0f46')
# (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-09ba')
# (0.5, 4, 'Blaster-X', 'CRWEAPONS-e5ab49-09f9')
# (0.5, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-09ea')
# (0.54, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0fa5')
# (0.6, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0cd5')
# (0.6, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0bcb')
# (0.65, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0bd6')
# (0.65, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-f3')
# (0.65, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0bd3')
# (1.0, 4, 'Boomstick-X', 'CRWEAPONS-e5ab49-0f84')
# (1.07, 4, 'Blaster-X', 'CRWEAPONS-e5ab49-0670')
# (1.1, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-076e')

# %%
for x in l:
    if x[1] > 1 and x[0] < 0.5:
        print(x)
# Out:
# (0.108, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0e9c')
# (0.13, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0ed3')
# (0.13, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0fee')
# (0.138, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0f6b')
# (0.14, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0c61')
# (0.145, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fb1')
# (0.148, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0f90')
# (0.149, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0ee1')
# (0.149, 5, 'Blaster-X', 'CRWEAPONS-e5ab49-0300')
# (0.149, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0729')
# (0.15, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0810')
# (0.15, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0931')
# (0.15, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0d84')
# (0.15, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0b42')
# (0.19, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0db8')
# (0.19, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0387')
# (0.19, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0999')
# (0.2, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-09e6')
# (0.2, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-01fb')
# (0.2, 4, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0cdc')
# (0.2, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0a39')
# (0.214, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0a22')
# (0.22, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0ff8')
# (0.22, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-081d')
# (0.26, 2, 'Blaster-X', 'CRWEAPONS-e5ab49-0c10')
# (0.27, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fcc')
# (0.27, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0fcd')
# (0.27, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-09ed')
# (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fef')
# (0.28, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0ffb')
# (0.29, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0f45')
# (0.3, 3, 'Boomstick-X', 'CRWEAPONS-e5ab49-0ffe')
# (0.3, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f68')
# (0.3, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-09d8')
# (0.3, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-0be9')
# (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe8')
# (0.3, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0fe7')
# (0.303, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0eb0')
# (0.319, 3, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0fc6')
# (0.32, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0f35')
# (0.38, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0fc0')
# (0.39, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-072a')
# (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0eae')
# (0.4, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-06e4')
# (0.4, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f41')
# (0.4, 2, 'Railgun-X', 'CRWEAPONS-e5ab49-0bd7')
# (0.4, 2, 'Mortar Gun X', 'CRWEAPONS-e5ab49-0654')
# (0.4, 2, 'Boomstick-X', 'CRWEAPONS-e5ab49-a1')
# (0.4, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0a25')
# (0.42, 5, 'Railgun-X', 'CRWEAPONS-e5ab49-0b0c')
# (0.43, 3, 'Blaster-X', 'CRWEAPONS-e5ab49-0f3f')
# (0.45, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0d01')
# (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-0a73')
# (0.45, 3, 'Tesla Gun X', 'CRWEAPONS-e5ab49-0f46')
# (0.45, 2, 'Tesla Gun X', 'CRWEAPONS-e5ab49-048a')
# (0.45, 3, 'Railgun-X', 'CRWEAPONS-e5ab49-09ba')

# %%
https://xoxno.com/nft/CRWEAPONS-e5ab49-0d27
https://xoxno.com/nft/CRWEAPONS-e5ab49-0c61
https://xoxno.com/nft/CRWEAPONS-e5ab49-0b5a
