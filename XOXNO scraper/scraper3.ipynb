# %%
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm
import json

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")

# options.add_argument("--headless")

options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
driver = webdriver.Chrome(options=options)

stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )

# %%
with open('results.json', 'r') as f:
    results = json.load(f)

# %%
for id in results:
    url = f'https://xoxno.com/collection/GSPACEAPE-08bc2b?filters=%7B%22name%22%3A%22{id}%22%2C%22order%22%3A%22Price%3A+Low+to+High%22%2C%22orderValue%22%3A%22saleInfoNft%2Fmin_bid_short+asc%22%2C%22tokens%22%3A%5B%5D%2C%22attributes%22%3A%5B%5D%2C%22saleType%22%3A%22Nft%22%2C%22tab%22%3A%22Listed%22%2C%22viewMode%22%3A%22cards%22%2C%22myFollowed%22%3Afalse%2C%22hasSecondNFT%22%3Afalse%2C%22marketplaces%22%3A%5B%5D%2C%22activityActions%22%3A%5B%5D%7D'
    driver.get(url)
    driver.find_element(By.CLASS_NAME, 'virtuoso-grid-item').find_element(By.TAG_NAME, 'img').click()
    break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /home/vincenzo/Documents/GitHub/Cantina-Royale-Analysis/XOXNO scraper/scraper3.ipynb Cella 3 line 4
#       <a href='vscode-notebook-cell:/home/vincenzo/Documents/GitHub/Cantina-Royale-Analysis/XOXNO%20scraper/scraper3.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> url = f'https://xoxno.com/collection/GSPACEAPE-08bc2b?filters=%7B%22name%22%3A%22{id}%22%2C%22order%22%3A%22Price%3A+Low+to+High%22%2C%22orderValue%22%3A%22saleInfoNft%2Fmin_bid_short+asc%22%2C%22tokens%22%3A%5B%5D%2C%22attributes%22%3A%5B%5D%2C%22saleType%22%3A%22Nft%22%2C%22tab%22%3A%22Listed%22%2C%22viewMode%22%3A%22cards%22%2C%22myFollowed%22%3Afalse%2C%22hasSecondNFT%22%3Afalse%2C%22marketplaces%22%3A%5B%5D%2C%22activityActions%22%3A%5B%5D%7D'
# ...

# %%
# Out:
# {'6876': {'verko': {'collectionName': 'Genesis Space Ape',
#    'gameData': [{'gameName': 'Cantina Royale',
#      'dynamicData': {'level': 1,
#       'character_tokens': 0,
#       'health': 2700,
#       'shield': 1400,
#       'talent_points_available': 0,
#       'talent_points_total': 0,
#       'earn_rate': 1,
#       'talents': [{'name': 'Overachiever', 'value': 0},
#        {'name': 'Hodler', 'value': 10},
#        {'name': 'Grounded', 'value': 0},
#        {'name': 'Stonewall', 'value': 0},
#        {'name': 'Adrenaline Rush', 'value': 0},
#        {'name': 'Overshield', 'value': 0},
#        {'name': 'Black Widow', 'value': 0},
#        {'name': 'Galvanized', 'value': 0},
#        {'name': 'Nano Meds', 'value': 0},
#        {'name': 'Resilience', 'value': 0},
#        {'name': 'Cold Blooded', 'value': 10},
#        {'name': 'Perseverance', 'value': 0},
#        {'name': 'Escape Artist', 'value': 0},
#        {'name': 'Scavenger', 'value': 0},
# ...

# %%
# level
# earn_rate
# perks
# attributes
