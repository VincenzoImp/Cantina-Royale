# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open('nfts.json', 'r') as f:
    data = json.load(f)

# %%
bronze = [ape['level'] for ape in data if ape['rarity'] == 'Bronze']
silver = [ape['level'] for ape in data if ape['rarity'] == 'Silver']
gold = [ape['level'] for ape in data if ape['rarity'] == 'Gold']
epic = [ape['level'] for ape in data if ape['rarity'] == 'Epic']
legend = [ape['level'] for ape in data if ape['rarity'] == 'Legendary']

# %%
l = [ape['level'] for ape in data if ape['level']>1]
plt.hist(l, bins=70, log=True)
plt.show()

# %%
d = {}

for ape in data:
    k = ", ".join(sorted([ape['perk1_name'], ape['perk2_name']]))
    try:
        d[k] += 1
    except KeyError:
        d[k] = 1
sorted(d.items(), key=lambda x: x[1])
# Out:
# [('Automatic Weapons, Overachiever', 26),
#  ('Cool Moves, Grounded', 26),
#  ('Automatic Weapons, Cool Moves', 27),
#  ('Elemental Weapons, Stonewall', 28),
#  ('Cool Moves, Stonewall', 29),
#  ('Elemental Weapons, Scatter Weapons', 30),
#  ('Elemental Weapons, Explosive Weapons', 31),
#  ('Resilience, Stonewall', 31),
#  ('Cool Moves, Resilience', 31),
#  ('Automatic Weapons, Elemental Weapons', 33),
#  ('Cool Moves, Explosive Weapons', 33),
#  ('Cool Moves, Escape Artist', 33),
#  ('Precision Weapons, Resilience', 33),
#  ('Brawler, Perseverance', 34),
#  ('Cool Moves, Elemental Weapons', 34),
#  ('Automatic Weapons, Explosive Weapons', 34),
#  ('Adrenaline Rush, Explosive Weapons', 35),
#  ('Explosive Weapons, Perseverance', 35),
#  ('Elemental Weapons, Grounded', 36),
#  ('Cool Moves, Perseverance', 36),
#  ('Overachiever, Resilience', 37),
#  ('Automatic Weapons, Stonewall', 38),
#  ('Explosive Weapons, Resilience', 38),
#  ('Black Widow, Stonewall', 38),
#  ('Escape Artist, Resilience', 38),
#  ('Resilience, Scavenger', 38),
#  ('Adrenaline Rush, Cool Moves', 39),
#  ('Automatic Weapons, Precision Weapons', 39),
#  ('Grounded, Resilience', 39),
#  ('Elemental Weapons, Scavenger', 39),
#  ('Cold Blooded, Resilience', 39),
#  ('Automatic Weapons, Black Widow', 40),
#  ('Galvanized, Scatter Weapons', 40),
#  ('Automatic Weapons, Resilience', 40),
#  ('Escape Artist, Stonewall', 40),
#  ('Cold Blooded, Scavenger', 40),
#  ('Automatic Weapons, Perseverance', 41),
#  ('Hodler, Stonewall', 41),
#  ('Automatic Weapons, Grounded', 42),
#  ('Scatter Weapons, Stonewall', 42),
#  ('Perseverance, Resilience', 42),
#  ('Automatic Weapons, Nano Meds', 42),
#  ('Cool Moves, Precision Weapons', 42),
#  ('Escape Artist, Scatter Weapons', 42),
#  ('Cool Moves, Galvanized', 42),
#  ('Cool Moves, Nano Meds', 43),
#  ('Elemental Weapons, Nano Meds', 43),
#  ('Cold Blooded, Stonewall', 43),
#  ('Cool Moves, Overshield', 43),
#  ('Explosive Weapons, Stonewall', 43),
#  ('Grounded, Overshield', 43),
#  ('Cool Moves, Overachiever', 43),
#  ('Elemental Weapons, Escape Artist', 44),
#  ('Adrenaline Rush, Automatic Weapons', 44),
#  ('Elemental Weapons, Resilience', 44),
#  ('Elemental Weapons, Overshield', 44),
#  ('Cool Moves, Scatter Weapons', 44),
#  ('Automatic Weapons, Cold Blooded', 44),
#  ('Cold Blooded, Cool Moves', 44),
#  ('Cool Moves, Scavenger', 45),
#  ('Automatic Weapons, Overshield', 45),
#  ('Brawler, Overachiever', 45),
#  ('Automatic Weapons, Hodler', 45),
#  ('Escape Artist, Nano Meds', 45),
#  ('Grounded, Stonewall', 45),
#  ('Brawler, Resilience', 45),
#  ('Galvanized, Stonewall', 45),
#  ('Automatic Weapons, Scatter Weapons', 45),
#  ('Elemental Weapons, Hodler', 45),
#  ('Brawler, Cool Moves', 45),
#  ('Adrenaline Rush, Overachiever', 45),
#  ('Brawler, Scavenger', 45),
#  ('Scavenger, Stonewall', 46),
#  ('Hodler, Overachiever', 46),
#  ('Cool Moves, Hodler', 46),
#  ('Automatic Weapons, Brawler', 46),
#  ('Elemental Weapons, Perseverance', 46),
#  ('Elemental Weapons, Galvanized', 46),
#  ('Precision Weapons, Stonewall', 46),
#  ('Escape Artist, Overshield', 47),
#  ('Black Widow, Cool Moves', 47),
#  ('Resilience, Scatter Weapons', 47),
#  ('Galvanized, Overshield', 47),
#  ('Automatic Weapons, Galvanized', 47),
#  ('Scatter Weapons, Scavenger', 47),
#  ('Galvanized, Grounded', 47),
#  ('Cold Blooded, Precision Weapons', 48),
#  ('Adrenaline Rush, Overshield', 48),
#  ('Black Widow, Resilience', 48),
#  ('Black Widow, Precision Weapons', 48),
#  ('Escape Artist, Grounded', 48),
#  ('Perseverance, Stonewall', 48),
#  ('Nano Meds, Overshield', 48),
#  ('Grounded, Scatter Weapons', 48),
#  ('Brawler, Precision Weapons', 48),
#  ('Overshield, Resilience', 49),
#  ('Precision Weapons, Scatter Weapons', 49),
#  ('Cold Blooded, Perseverance', 49),
#  ('Adrenaline Rush, Stonewall', 49),
#  ('Explosive Weapons, Nano Meds', 50),
#  ('Galvanized, Resilience', 50),
#  ('Black Widow, Elemental Weapons', 50),
#  ('Nano Meds, Resilience', 50),
#  ('Automatic Weapons, Escape Artist', 50),
#  ('Nano Meds, Stonewall', 50),
#  ('Overachiever, Overshield', 50),
#  ('Adrenaline Rush, Galvanized', 50),
#  ('Adrenaline Rush, Nano Meds', 50),
#  ('Elemental Weapons, Overachiever', 51),
#  ('Brawler, Stonewall', 51),
#  ('Adrenaline Rush, Black Widow', 51),
#  ('Brawler, Overshield', 51),
#  ('Black Widow, Explosive Weapons', 52),
#  ('Grounded, Nano Meds', 52),
#  ('Explosive Weapons, Galvanized', 52),
#  ('Galvanized, Scavenger', 52),
#  ('Black Widow, Escape Artist', 52),
#  ('Black Widow, Galvanized', 52),
#  ('Automatic Weapons, Scavenger', 53),
#  ('Black Widow, Scatter Weapons', 53),
#  ('Overachiever, Precision Weapons', 53),
#  ('Precision Weapons, Scavenger', 53),
#  ('Escape Artist, Overachiever', 53),
#  ('Escape Artist, Perseverance', 53),
#  ('Galvanized, Overachiever', 53),
#  ('Cold Blooded, Escape Artist', 53),
#  ('Overshield, Perseverance', 53),
#  ('Nano Meds, Precision Weapons', 54),
#  ('Grounded, Perseverance', 54),
#  ('Elemental Weapons, Precision Weapons', 54),
#  ('Adrenaline Rush, Scatter Weapons', 54),
#  ('Overachiever, Scavenger', 54),
#  ('Adrenaline Rush, Precision Weapons', 54),
#  ('Cold Blooded, Galvanized', 54),
#  ('Adrenaline Rush, Hodler', 54),
#  ('Cold Blooded, Nano Meds', 55),
#  ('Escape Artist, Explosive Weapons', 55),
#  ('Galvanized, Perseverance', 55),
#  ('Brawler, Galvanized', 55),
#  ('Galvanized, Nano Meds', 55),
#  ('Explosive Weapons, Overachiever', 55),
#  ('Brawler, Explosive Weapons', 55),
#  ('Brawler, Scatter Weapons', 55),
#  ('Brawler, Escape Artist', 55),
#  ('Hodler, Overshield', 55),
#  ('Cold Blooded, Overshield', 55),
#  ('Brawler, Elemental Weapons', 56),
#  ('Overachiever, Stonewall', 56),
#  ('Black Widow, Hodler', 56),
#  ('Overshield, Precision Weapons', 56),
#  ('Hodler, Scatter Weapons', 56),
#  ('Escape Artist, Hodler', 56),
#  ('Brawler, Nano Meds', 56),
#  ('Cold Blooded, Elemental Weapons', 56),
#  ('Nano Meds, Overachiever', 56),
#  ('Hodler, Resilience', 56),
#  ('Galvanized, Precision Weapons', 56),
#  ('Adrenaline Rush, Scavenger', 56),
#  ('Adrenaline Rush, Escape Artist', 57),
#  ('Adrenaline Rush, Cold Blooded', 57),
#  ('Perseverance, Precision Weapons', 58),
#  ('Brawler, Grounded', 58),
#  ('Overshield, Scatter Weapons', 58),
#  ('Adrenaline Rush, Grounded', 58),
#  ('Hodler, Perseverance', 59),
#  ('Explosive Weapons, Grounded', 59),
#  ('Escape Artist, Galvanized', 59),
#  ('Grounded, Precision Weapons', 59),
#  ('Adrenaline Rush, Elemental Weapons', 60),
#  ('Escape Artist, Precision Weapons', 60),
#  ('Nano Meds, Perseverance', 60),
#  ('Adrenaline Rush, Brawler', 60),
#  ('Overshield, Stonewall', 60),
#  ('Black Widow, Scavenger', 60),
#  ('Explosive Weapons, Precision Weapons', 60),
#  ('Explosive Weapons, Hodler', 61),
#  ('Nano Meds, Scatter Weapons', 61),
#  ('Explosive Weapons, Scavenger', 61),
#  ('Cold Blooded, Explosive Weapons', 61),
#  ('Galvanized, Hodler', 61),
#  ('Cold Blooded, Hodler', 61),
#  ('Black Widow, Overachiever', 61),
#  ('Black Widow, Brawler', 61),
#  ('Overachiever, Scatter Weapons', 61),
#  ('Adrenaline Rush, Resilience', 61),
#  ('Escape Artist, Scavenger', 63),
#  ('Brawler, Hodler', 63),
#  ('Black Widow, Nano Meds', 63),
#  ('Perseverance, Scavenger', 63),
#  ('Grounded, Overachiever', 63),
#  ('Perseverance, Scatter Weapons', 63),
#  ('Cold Blooded, Grounded', 63),
#  ('Cold Blooded, Scatter Weapons', 63),
#  ('Overachiever, Perseverance', 63),
#  ('Black Widow, Cold Blooded', 64),
#  ('Black Widow, Overshield', 65),
#  ('Nano Meds, Scavenger', 65),
#  ('Grounded, Hodler', 65),
#  ('Cold Blooded, Overachiever', 65),
#  ('Hodler, Nano Meds', 66),
#  ('Black Widow, Perseverance', 66),
#  ('Hodler, Precision Weapons', 66),
#  ('Brawler, Cold Blooded', 67),
#  ('Explosive Weapons, Scatter Weapons', 67),
#  ('Black Widow, Grounded', 68),
#  ('Overshield, Scavenger', 68),
#  ('Hodler, Scavenger', 69),
#  ('Adrenaline Rush, Perseverance', 70),
#  ('Grounded, Scavenger', 72),
#  ('Explosive Weapons, Overshield', 72)]
